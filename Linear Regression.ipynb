# %%
import pandas
from pandas import DataFrame
import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression

# %%
data = pandas.read_csv('cost_revenue_clean.csv')

# %%
data.describe()
# Out:
#        production_budget_usd  worldwide_gross_usd
# count           5.034000e+03         5.034000e+03
# mean            3.290784e+07         9.515685e+07
# std             4.112589e+07         1.726012e+08
# min             1.100000e+03         2.600000e+01
# 25%             6.000000e+06         7.000000e+06
# 50%             1.900000e+07         3.296202e+07
# 75%             4.200000e+07         1.034471e+08
# max             4.250000e+08         2.783919e+09

# %%
X = DataFrame(data, columns=['production_budget_usd'])
y = DataFrame(data, columns=['worldwide_gross_usd'])

# %%
# creating charts
plt.figure(figsize=(10, 6))
plt.scatter(X, y, alpha=0.3)
plt.title('Film cost VS Global revenue')
plt.xlabel('Production budget $')
plt.ylabel('Worldwide gross $')
plt.ylim(0, 3000000000)
plt.xlim(0, 450000000)
plt.show()

# %% [markdown]
# Slope coefficient

# %%
regression = LinearRegression()
regression.fit(X, y)
# Out:
# LinearRegression()

# %%
regression.coef_ # theta_1
# Out:
# array([[3.11150918]])

# %%
#intercept 
regression.intercept_
# Out:
# array([-7236192.72913988])

# %%
# creating charts
plt.figure(figsize=(10, 6))
plt.scatter(X, y, alpha=0.3)
plt.plot(X.to_numpy(), regression.predict(X.to_numpy()), color='red',linewidth=4 )
plt.title('Film cost VS Global revenue')
plt.xlabel('Production budget $')
plt.ylabel('Worldwide gross $')
plt.ylim(0, 3000000000)
plt.xlim(0, 450000000)
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
#goodnes or fit. 55% of the variation we see in worlwide movie earnings.
regression.score(X, y)
# Out:
# 0.5496485356985729
